# %%
import time
import io
import numpy as np
import matplotlib.pyplot as plt

# %%
from rembg import remove
import cv2

input_path = 'input.jpg'
output_path = 'output.png'

input = cv2.imread(input_path)
output = remove(input)
cv2.imwrite(output_path, output)
# Out:
# True

# %%
from rembg import remove
import cv2

input_path = 'input2.jpg'
output_path = 'output2.png'

input = cv2.imread(input_path)
output = remove(input)
cv2.imwrite(output_path, output)
# Out:
# True

# %% [markdown]
# ![output.png](attachment:output.png)

# %%
from rembg import remove
import cv2

for i in range(1,11):
    input_path = 'input_test/'+str(i)+'_short_pants.png'
    output_path = 'output_test/'+str(i)+'_short_pants.png'

    input_re = cv2.imread(input_path)
    output = remove(input_re)
    cv2.imwrite(output_path, output)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [4], in <cell line: 4>()
#       6 output_path = 'output_test/'+str(i)+'_short_pants.png'
#       8 input_re = cv2.imread(input_path)
# ----> 9 output = remove(input_re)
#      10 cv2.imwrite(output_path, output)
#
# File ~\miniconda3\envs\py38-env2\lib\site-packages\rembg\bg.py:130, in remove(data, alpha_matting, alpha_matting_foreground_threshold, alpha_matting_background_threshold, alpha_matting_erode_size, session, only_mask, post_process_mask)
#     128     img = Image.fromarray(data)
#     129 else:
# --> 130     raise ValueError("Input type {} is not supported.".format(type(data)))
#     132 if session is None:
#     133     session = new_session("u2net")
#
# ValueError: Input type <class 'NoneType'> is not supported.

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from PIL import Image
import colorsys
import seaborn as sns

# %%
import cv2
img = cv2.imread('output2.png',0)
hist = cv2.calcHist([img],[0],None,[256],[0,256])

# %%
import cv2
from matplotlib import pyplot as plt
img = cv2.imread('output2.png',0)
plt.hist(img.ravel(), 256, [0,256]); 
plt.show()

# %%
sns.set()
sns.distplot(make_h_list(pix), kde=True, rug=False)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [10], in <cell line: 2>()
#       1 sns.set()
# ----> 2 sns.distplot(make_h_list(pix), kde=True, rug=False)
#       3 plt.show()
#
# Input In [9], in make_h_list(pix_rgb)
#       3 for i in pix_rgb:
#       4     for j in i:
# ----> 5         h_list.append(revised_rgb_to_hsv(j[0], j[1]. j[2])[0])
#       6 return h_list
#
# AttributeError: 'numpy.uint8' object has no attribute 'j'

# %%
import cv2
from matplotlib import pyplot as plt
img = cv2.imread('output2.png')
color = ('b','g','r')
for i,col in enumerate(color):
    histr = cv2.calcHist([img],[i],None,[256],[0,256])
    plt.plot(histr,color = col)
    plt.xlim([0,256])
plt.show()

# %%
from colorthief import ColorThief
import matplotlib.pyplot as plt
import colorsys

# %%
ct = ColorThief("output2.png")
dominant_color = ct.get_color(quality=1)
plt.imshow([[dominant_color]])
plt.show()

# %%
palette = ct.get_palette(color_count=5)
plt.imshow([[palette[i] for i in range(5)]])
plt.show()

# %%
from collections import Counter
from sklearn.cluster import KMeans
from matplotlib import colors
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
image = cv2.imread('output2.png')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)

# %%
im = Image.open('output2.png')
rgb_im = im.convert('RGB')
r, g, b = rgb_im.getpixel((1, 1))

print(r, g, b)
(65, 100, 137)
# Out:
# 0 0 0
# (65, 100, 137)

# %%
import extcolors
from PIL import Image


img = Image.open("output2.png")
colors, pixel_count = extcolors.extract_from_image(img)

pixel_output = 0
for c in colors:
    pixel_output += c[1]
    print(f'{c[0]} : {round((c[1] / pixel_count) * 100, 2)}% ({c[1]})')
print(f'Pixels in output: {pixel_output} of {pixel_count}')
# Out:
# (31, 32, 37) : 43.93% (109833)
# (105, 105, 107) : 0.09% (219)
# (185, 188, 205) : 0.05% (127)
# Pixels in output: 110179 of 250000

# %%
a = [31, 32, 37]
black = [0, 0, 0]
count=[]

for a, black in zip(a, black):
    print(a, black, abs(a-black))
    count.append(a-black)
    
print(count)
# Out:
# 31 0 31
# 32 0 32
# 37 0 37
# [31, 32, 37]

# %%
a = [31, 32, 37]
charcoal = [54, 69, 79]
count=[]

for a, charcoal in zip(a, charcoal):
    print(a, charcoal, abs(a-charcoal))
    count.append(a-charcoal)
    
print(count)

colorSum = sum(count)
print(colorSum)
# Out:
# 31 54 23
# 32 69 37
# 37 79 42
# [-23, -37, -42]
# -102

# %%
greenyellow = [173, 255, 47]
yellow = [255, 255, 0]
orange = [255, 165, 0]
white = [255, 255, 255]
black = [0, 0, 0]
pink = [255, 192, 203]
brown = [165, 42, 42]
blue = [0, 0, 255]
red = [255, 0, 0]
purple = [128, 0, 128]
gray = [128, 128, 128]
ivory = [255, 255, 240]
beige = [245, 245, 220]
charcoal = [54, 69, 79]
skyblue = [115, 194, 251]
navy = [0, 0, 128]
